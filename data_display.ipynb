# %%
import pandas as pd
from pandas import DataFrame
from sqlalchemy import create_engine, Engine

# %%
query: str = """SELECT * 
                FROM datas
                ORDER BY serie ASC, edition_id ASC, number ASC;
        """

# %%
engine: Engine = create_engine("postgresql+psycopg2://shooterdev:azenbvqsdmlk@127.0.0.1:5433/scrasp_mangatheque")

df: DataFrame = pd.read_sql(query, engine, 'index')
#df: DataFrame = pd.read_csv("/Users/shooterdev/Labs/PycharmProjects/scrap_mangacollec/csv/L'Attaque des Titans.csv")
df = df.drop_duplicates()

# %%
df.columns
# Out:
# Index(['id', 'title', 'number', 'release_date', 'isbn', 'asin', 'edition_id',
#        'possessions_count', 'not_sold', 'image_url', 'YEAR', 'MONTH', 'DAY',
#        'HOUR', 'kind', 'serie', 'genre', 'publisher', 'edition_title',
#        'edition_volumes_count', 'commercial_stop', 'last_volume_number',
#        'not_finished', 'follow_editions_count', 'parent_edition_id',
#        'authors'],
#       dtype='object')

# %%
df.head
# Out:
# <bound method NDFrame.head of                                          id title  number release_date  \
# index
# 193    30de6db1-033a-4ed7-b3e3-678e5c4a4a80  None      98   2021-05-19
# 196    e3b0efec-d8df-441f-bc69-7db72d7d927f  None      99   2021-09-15
# 197    6811a9d0-ec55-42cf-9460-951302750ba0  None     100   2021-12-08
# 211    9007e7fc-fb9e-4481-abd0-d7b703c99009  None       1   2000-09-20
# 212    767a11d2-095f-4fbe-a1e7-897a41ca04ee  None       2   2000-11-22
# ...                                     ...   ...     ...          ...
# 25     80cfe8d1-84ab-4a59-8956-4cdb416c8fd2  None      36   2016-12-28
# 24     c6cf36a8-23ba-4490-bd93-ef08fd7ce3ce  None      37   2017-01-11
# 0      7c8db2b2-36a1-4944-ab78-3e00ab1cfdd4  None      38   2017-01-25
# 77     8429613e-e7aa-4e88-b25c-12d26eb042ea  None      39   2017-02-08
# 157    f7f4b31b-dae0-4503-8585-24d656a9539c  None      40   2017-02-22
#
#                 isbn        asin                            edition_id  \
# ...

# %%
df.describe()
# Out:
#            number  possessions_count    YEAR  MONTH    DAY   HOUR  \
# count  223.000000         223.000000   223.0  223.0  223.0  223.0
# mean    43.816143       28202.538117  2025.0    5.0    8.0   21.0
# std     29.995455       29458.502399     0.0    0.0    0.0    0.0
# min      1.000000          59.000000  2025.0    5.0    8.0   21.0
# 25%     19.000000        2397.500000  2025.0    5.0    8.0   21.0
# 50%     38.000000       11382.000000  2025.0    5.0    8.0   21.0
# 75%     64.000000       49575.500000  2025.0    5.0    8.0   21.0
# max    110.000000      124733.000000  2025.0    5.0    8.0   21.0
#
#        edition_volumes_count  last_volume_number  follow_editions_count
# count             223.000000          110.000000             223.000000
# mean               81.080717           57.272727           76825.331839
# std                31.233395           13.634084           70245.662019
# min                 3.000000           40.000000            2462.000000
# ...

# %%
df.mode(numeric_only=True)
# Out:
#     number  possessions_count not_sold    YEAR  MONTH  DAY  HOUR  \
# 0        1              682.0    False  2025.0    5.0  8.0  21.0
# 1        2             2464.0      NaN     NaN    NaN  NaN   NaN
# 2        3                NaN      NaN     NaN    NaN  NaN   NaN
# 3        4                NaN      NaN     NaN    NaN  NaN   NaN
# 4        5                NaN      NaN     NaN    NaN  NaN   NaN
# 5        6                NaN      NaN     NaN    NaN  NaN   NaN
# 6        7                NaN      NaN     NaN    NaN  NaN   NaN
# 7        8                NaN      NaN     NaN    NaN  NaN   NaN
# 8        9                NaN      NaN     NaN    NaN  NaN   NaN
# 9       10                NaN      NaN     NaN    NaN  NaN   NaN
# 10      11                NaN      NaN     NaN    NaN  NaN   NaN
# 11      12                NaN      NaN     NaN    NaN  NaN   NaN
# 12      13                NaN      NaN     NaN    NaN  NaN   NaN
# ...

# %% [markdown]
# # Moyene

# %%
df.mean(numeric_only=True)
# Out:
# number                      43.816143
# possessions_count        28202.538117
# not_sold                     0.206278
# YEAR                      2025.000000
# MONTH                        5.000000
# DAY                          8.000000
# HOUR                        21.000000
# edition_volumes_count       81.080717
# commercial_stop              0.295964
# last_volume_number          57.272727
# not_finished                 0.295964
# follow_editions_count    76825.331839
# dtype: float64

# %%
df['kind']
# Out:
# index
# 193    {Action,Aventure,Combat,Comédie,Fantasy,Pirate...
# 196    {Action,Aventure,Combat,Comédie,Fantasy,Pirate...
# 197    {Action,Aventure,Combat,Comédie,Fantasy,Pirate...
# 211    {Action,Aventure,Combat,Comédie,Fantasy,Pirate...
# 212    {Action,Aventure,Combat,Comédie,Fantasy,Pirate...
#                              ...
# 25     {Action,Aventure,Combat,Comédie,Fantasy,Pirate...
# 24     {Action,Aventure,Combat,Comédie,Fantasy,Pirate...
# 0      {Action,Aventure,Combat,Comédie,Fantasy,Pirate...
# 77     {Action,Aventure,Combat,Comédie,Fantasy,Pirate...
# 157    {Action,Aventure,Combat,Comédie,Fantasy,Pirate...
# Name: kind, Length: 223, dtype: object

# %%
df[['not_sold','possessions_count']].value_counts()
# Out:
# not_sold  possessions_count
# False     2464                 2
# True      682                  2
# False     2246                 1
#           2306                 1
#           2275                 1
#                               ..
# True      1421                 1
#           1479                 1
#           1494                 1
#           1658                 1
#           2251                 1
# Name: count, Length: 221, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'title', 'number', 'release_date', 'isbn', 'asin', 'edition_id',
#        'possessions_count', 'not_sold', 'image_url', 'YEAR', 'MONTH', 'DAY',
#        'HOUR', 'kind', 'serie', 'genre', 'publisher', 'edition_title',
#        'edition_volumes_count', 'commercial_stop', 'last_volume_number',
#        'not_finished', 'follow_editions_count', 'parent_edition_id',
#        'authors'],
#       dtype='object')

# %%
df[['last_volume_number']].corr()
# Out:
#                     last_volume_number
# last_volume_number                 1.0

# %% [markdown]
# # CLEAN

# %%
df = df.drop_duplicates(subset=['YEAR', 'MONTH', 'DAY', 'HOUR', 'id'])
df.to_sql(name="data_clean", con=engine, if_exists="replace")
df.to_sql(name="datas", con=engine, if_exists="replace")
# Out:
# 223
